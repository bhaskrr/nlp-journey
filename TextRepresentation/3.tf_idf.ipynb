# %% [markdown]
# # Term Frequency-Inverse Document Frequency (TF-IDF)
#
# TF-IDF stands for Term Frequency Inverse Document Frequency of records. It can be defined as the calculation of how relevant a word in a series or corpus is to a text. The meaning increases proportionally to the number of times in the text a word appears but is compensated by the word frequency in the corpus (data-set).
#
# ## Terminologies:
#
# 1. Term Frequency: In document d, the frequency represents the number of instances of a given word t. Therefore, we can see that it becomes more relevant when a word appears in the text, which is rational. Since the ordering of terms is not significant, we can use a vector to describe the text in the bag of term models. For each specific term in the paper, there is an entry with the value being the term frequency.
#
#     The weight of a term that occurs in a document is simply proportional to the term frequency.
#
#     tf(t,d) = count of t in d / number of words in d
#
# 2. Document Frequency: This tests the meaning of the text, which is very similar to TF, in the whole corpus collection. The only difference is that in document d, TF is the frequency counter for a term t, while df is the number of occurrences in the document set N of the term t. In other words, the number of papers in which the word is present is DF.
#
#     df(t) = occurrence of t in documents
#
# 3. Inverse Document Frequency: Mainly, it tests how relevant the word is. The key aim of the search is to locate the appropriate records that fit the demand. Since tf considers all terms equally significant, it is therefore not only possible to use the term frequencies to measure the weight of the term in the paper. First, find the document frequency of a term t by counting the number of documents containing the term:
#
#     df(t) = N(t)
#
#     where,
#
#     * df(t) = Document frequency of a term t
#
#     * N(t) = Number of documents containing the term t
#
#     Term frequency is the number of instances of a term in a single document only; although the frequency of the document is the number of separate documents in which the term appears, it depends on the entire corpus. Now let’s look at the definition of the frequency of the inverse paper. The IDF of the word is the number of documents in the corpus separated by the frequency of the text.
#
#     idf(t) = N/ df(t) = N/N(t)
#
#     The more common word is supposed to be considered less significant, but the element (most definite integers) seems too harsh. We then take the logarithm (with base 2) of the inverse frequency of the paper. So the idf of the term t becomes:
#
#     idf(t) = log(N/ df(t))
#
# Tf-idf is one of the best metrics to determine how significant a term is to a text in a series or a corpus. tf-idf is a weighting system that assigns a weight to each word in a document based on its term frequency (tf) and the reciprocal document frequency (idf). The words with higher scores of weight are deemed to be more significant.

# %% [markdown]
# ## Fake News Detection using TF-IDF

# %%
# Import required libraries
import pandas as pd
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Load spacy's english model
nlp = spacy.load("en_core_web_sm")

# %%
# Load and inspect data
data = pd.read_csv("./fake_and_real_news.csv")
data.head()
# Out:
#                                                 Text label
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...  Fake
# 1  U.S. conservative leader optimistic of common ...  Real
# 2  Trump proposes U.S. tax overhaul, stirs concer...  Real
# 3   Court Forces Ohio To Allow Millions Of Illega...  Fake
# 4  Democrats say Trump agrees to work on immigrat...  Real

# %%
# Unique values in label column
print(data["label"].unique())

# Class distribution of the data
print(data["label"].value_counts())
# Out:
# ['Fake' 'Real']
# label
# Fake    5000
# Real    4900
# Name: count, dtype: int64

# %%
# So, the data contains two labels: "Fake" and "Real".
# Now we will convert them into integer labels
# Representing Real with 0 and Fake with 1

# Define the label mappings
label_map = {
    "Real": 0,
    "Fake": 1
}

# Apply label mappings to the label column
data["label"] = data["label"].apply(lambda x: label_map[x])
data.head()
# Out:
#                                                 Text  label
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...      1
# 1  U.S. conservative leader optimistic of common ...      0
# 2  Trump proposes U.S. tax overhaul, stirs concer...      0
# 3   Court Forces Ohio To Allow Millions Of Illega...      1
# 4  Democrats say Trump agrees to work on immigrat...      0

# %%
# Function to preprocess the text
def preprocess(text):
    text = text.lower()
    doc = nlp(text)
    
    # Apply lowercasing and lemmatization if the token is alphanumeric and is not a punctuation
    processed_tokens = [token.lemma_ for token in doc if token.is_alpha and not token.is_punct]
    
    return " ".join(processed_tokens)

data["clean_text"] = data["Text"].apply(lambda x: preprocess(x))
data.head()
# Out:
#                                                 Text  ...                                         clean_text
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...  ...  top trump surrogate brutally stab he in the ba...
# 1  U.S. conservative leader optimistic of common ...  ...  conservative leader optimistic of common groun...
# 2  Trump proposes U.S. tax overhaul, stirs concer...  ...  trump propose tax overhaul stir concern on def...
# 3   Court Forces Ohio To Allow Millions Of Illega...  ...  court force ohio to allow million of illegally...
# 4  Democrats say Trump agrees to work on immigrat...  ...  democrats say trump agree to work on immigrati...
#
# [5 rows x 3 columns]

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    data["clean_text"],
    data["label"],
    shuffle=True,
    random_state=42
)

# Shapes
print("X_train shape: ", X_train.shape)
print("X_test shape: ", X_test.shape)
print("y_train shape: ", y_train.shape)
print("y_test shape: ", y_test.shape)
# Out:
# X_train shape:  (7425,)
# X_test shape:  (2475,)
# y_train shape:  (7425,)
# y_test shape:  (2475,)

# %%
# Extract TfIdf Vectors
vectorizer = TfidfVectorizer(max_features=2000)

X_train_vect = vectorizer.fit_transform(X_train.values)
X_test_vect = vectorizer.transform(X_test.values)

# %%
# Vocabulary
vectorizer.vocabulary_
# Out:
# {'fact': 635,
#  'check': 292,
#  'intelligence': 885,
#  'prove': 1387,
#  'trump': 1844,
#  'liar': 1006,
#  'he': 787,
#  'know': 962,
#  'about': 5,
#  'russian': 1542,
#  'attack': 150,
#  'donald': 528,
#  'seem': 1583,
#  'to': 1812,
#  'be': 179,
#  'when': 1944,
#  'it': 913,
#  'come': 338,
#  'cyber': 435,
#  'security': 1580,
#  'threat': 1801,
#  'display': 515,
#  'this': 1796,
#  'once': 1209,
#  'again': 48,
#  'during': 543,
#  'the': 1784,
#  'second': 1574,
#  'presidential': 1341,
#  'state': 1690,
#  'that': 1783,
#  'didn': 495,
#  'whether': 1946,
#  'there': 1789,
#  'in': 855,
#  'regard': 1450,
#  'hack': 767,
#  'and': 93,
#  'election': 563,
#  'but': 245,
#  'an': 90,
#  'lie': 1009,
#  'have': 784,
#  'brief': 230,
#  'on': 1208,
#  'very': 1888,
#  'nbc': 1144,
#  'news': 1157,
#  'senior': 1591,
#  'official': 1201,
#  'government': 750,
#  'attempt': 151,
#  'interfere': 888,
#  'discuss': 511,
#  'with': 1966,
#  'both': 222,
#  'party': 1261,
#  'candidate': 257,
#  'leadership': 989,
#  'since': 1636,
#  'august': 156,
#  'not': 1175,
#  'at': 149,
#  'point': 1306,
#  'say': 1558,
#  'community': 348,
#  'walk': 1914,
#  'line': 1017,
#  'take': 1753,
#  'side': 1628,
#  'all': 66,
#  'information': 870,
#  'they': 1792,
#  'need': 1148,
#  'clear': 317,
#  'without': 1969,
#  'doubt': 532,
#  'either': 561,
#  'or': 1224,
#  'debate': 452,
#  'notice': 1178,
#  'anything': 109,
#  'wrong': 1985,
#  'happen': 775,
#  'like': 1013,
#  'russians': 1543,
#  'hillary': 805,
#  'clinton': 321,
#  'doesn': 523,
#  'if': 836,
#  'do': 520,
#  'maybe': 1064,
#  'no': 1165,
#  'always': 81,
#  'blame': 208,
#  'russia': 1541,
#  'reason': 1434,
#  'because': 182,
#  'think': 1794,
#  're': 1424,
#  'try': 1848,
#  'nothing': 1177,
#  'literally': 1021,
#  'bring': 232,
#  'back': 165,
#  'himself': 806,
#  'talk': 1754,
#  'realize': 1432,
#  'up': 1875,
#  'express': 629,
#  'critical': 423,
#  'of': 1195,
#  'increase': 861,
#  'you': 1995,
#  'actual': 22,
#  'go': 743,
#  'beyond': 196,
#  'briefing': 231,
#  'make': 1045,
#  'statement': 1691,
#  'public': 1392,
#  'for': 694,
#  'we': 1927,
#  'direct': 503,
#  'recent': 1436,
#  'compromise': 356,
#  'from': 713,
#  'person': 1287,
#  'institution': 879,
#  'include': 859,
#  'political': 1310,
#  'organization': 1227,
#  'so': 1649,
#  'question': 1405,
#  'why': 1955,
#  'ignore': 837,
#  'issue': 912,
#  'protect': 1383,
#  'may': 1063,
#  'business': 244,
#  'tie': 1808,
#  'wouldn': 1982,
#  'win': 1961,
#  'release': 1461,
#  'his': 808,
#  'taxis': 1762,
#  'already': 76,
#  'how': 824,
#  'much': 1126,
#  'love': 1036,
#  'president': 1340,
#  'vladimir': 1905,
#  'putin': 1403,
#  'definitely': 468,
#  'accord': 11,
#  'washington': 1921,
#  'post': 1326,
#  'strong': 1716,
#  'evidence': 611,
#  'receive': 1435,
#  'significant': 1632,
#  'funding': 721,
#  'investor': 901,
#  'most': 1118,
#  'son': 1660,
#  'jr': 938,
#  'claim': 313,
#  'real': 1430,
#  'estate': 597,
#  'conference': 364,
#  'new': 1156,
#  'york': 1994,
#  'pretty': 1345,
#  'cross': 426,
#  'section': 1577,
#  'lot': 1035,
#  'our': 1231,
#  'asset': 144,
#  'add': 26,
#  'see': 1581,
#  'money': 1112,
#  'which': 1947,
#  'lead': 987,
#  'many': 1052,
#  'believe': 190,
#  'would': 1981,
#  'more': 1115,
#  'republican': 1484,
#  'however': 825,
#  'll': 1024,
#  'likely': 1014,
#  'damage': 438,
#  'probably': 1360,
#  'keep': 947,
#  'those': 1797,
#  'close': 322,
#  'orange': 1225,
#  'report': 1478,
#  'via': 1891,
#  'feature': 653,
#  'photo': 1291,
#  'by': 247,
#  'mcnamee': 1068,
#  'getty': 738,
#  'image': 841,
#  'fbi': 650,
#  'warn': 1918,
#  'republicans': 1485,
#  'leak': 990,
#  'email': 568,
#  'file': 666,
#  'secret': 1575,
#  'find': 673,
#  'something': 1657,
#  'down': 533,
#  'idea': 834,
#  'third': 1795,
#  'term': 1773,
#  'democrat': 473,
#  'hand': 772,
#  'woman': 1971,
#  'hell': 794,
#  'out': 1232,
#  'what': 1942,
#  'good': 747,
#  'department': 479,
#  'justice': 945,
#  'any': 106,
#  'criminal': 420,
#  'face': 633,
#  'hit': 810,
#  'wall': 1915,
#  'charge': 289,
#  'who': 1951,
#  'her': 796,
#  'chance': 285,
#  'become': 183,
#  'america': 84,
#  'next': 1159,
#  'part': 1255,
#  'over': 1237,
#  'member': 1080,
#  'congress': 369,
#  'document': 522,
#  'detail': 489,
#  'witness': 1970,
#  'interview': 894,
#  'secretary': 1576,
#  'along': 75,
#  'other': 1229,
#  'material': 1060,
#  'now': 1181,
#  'age': 50,
#  'internet': 893,
#  'almost': 73,
#  'get': 736,
#  'their': 1785,
#  'potentially': 1328,
#  'politically': 1311,
#  'different': 498,
#  'some': 1653,
#  'as': 136,
#  'situation': 1640,
#  'hope': 816,
#  'use': 1880,
#  'these': 1791,
#  'gun': 765,
#  'court': 413,
#  'opinion': 1218,
#  'law': 982,
#  'fall': 640,
#  'one': 1210,
#  'classified': 315,
#  'should': 1623,
#  'staff': 1682,
#  'personally': 1289,
#  'feel': 659,
#  'provide': 1388,
#  'remind': 1469,
#  'commitment': 344,
#  'respect': 1497,
#  'investigation': 898,
#  'former': 699,
#  'personal': 1288,
#  'certain': 278,
#  'appropriate': 119,
#  'congressional': 370,
#  'committee': 345,
#  'oversight': 1242,
#  'responsibility': 1500,
#  'matter': 1061,
#  'contain': 383,
#  'sensitive': 1593,
#  'will': 1958,
#  'disclose': 508,
#  'someone': 1656,
#  'capitol': 260,
#  'hill': 804,
#  'could': 403,
#  'pursue': 1400,
#  'stupid': 1722,
#  'enough': 583,
#  'allow': 71,
#  'such': 1728,
#  'high': 801,
#  'ground': 758,
#  'argument': 127,
#  'handle': 773,
#  'completely': 354,
#  'campaign': 253,
#  'announce': 98,
#  'want': 1916,
#  'off': 1196,
#  'gop': 748,
#  'step': 1698,
#  'seek': 1582,
#  'purpose': 1399,
#  'further': 723,
#  'guess': 763,
#  'career': 264,
#  'share': 1613,
#  'outside': 1235,
#  'can': 254,
#  'themselves': 1786,
#  'rather': 1422,
#  'than': 1781,
#  'through': 1804,
#  'partisan': 1259,
#  'continue': 385,
#  'put': 1402,
#  'tax': 1761,
#  'return': 1507,
#  'call': 250,
#  'near': 1145,
#  'total': 1819,
#  'surround': 1744,
#  'scandal': 1559,
#  'she': 1614,
#  'link': 1018,
#  'everything': 610,
#  've': 1885,
#  'work': 1975,
#  'staffer': 1683,
#  'decide': 457,
#  'conservative': 374,
#  'hero': 798,
#  'mark': 1055,
#  'session': 1603,
#  'let': 1002,
#  'racist': 1413,
#  'joe': 929,
#  'month': 1113,
#  'ago': 54,
#  'just': 944,
#  'throw': 1806,
#  'nation': 1137,
#  'county': 410,
#  'arizona': 128,
#  'guy': 766,
#  'refuse': 1449,
#  'follow': 691,
#  'order': 1226,
#  'stop': 1706,
#  'profile': 1368,
#  'people': 1276,
#  'year': 1988,
#  'consequence': 373,
#  'able': 3,
#  'carry': 266,
#  'even': 602,
#  'jeff': 924,
#  'sessions': 1604,
#  'drop': 539,
#  'case': 267,
#  'against': 49,
#  'tell': 1769,
#  'action': 19,
#  'thing': 1793,
#  'choice': 300,
#  'wait': 1912,
#  'until': 1873,
#  'then': 1787,
#  'perfect': 1279,
#  'time': 1810,
#  'white': 1950,
#  'house': 823,
#  'prepare': 1337,
#  'moment': 1110,
#  'course': 412,
#  'forget': 697,
#  'partner': 1260,
#  'crime': 419,
#  'ever': 606,
#  'start': 1689,
#  'promote': 1375,
#  'obama': 1186,
#  'bear': 180,
#  'united': 1868,
#  'states': 1692,
#  'first': 678,
#  'black': 207,
#  'chief': 295,
#  'short': 1620,
#  'two': 1855,
#  'wasn': 1922,
#  'man': 1046,
#  'jail': 918,
#  'though': 1798,
#  'deserve': 484,
#  'show': 1624,
#  'willing': 1959,
#  'truly': 1843,
#  'maintain': 1042,
#  'least': 993,
#  'little': 1022,
#  'push': 1401,
#  'mueller': 1127,
#  'please': 1304,
#  'rid': 1521,
#  'while': 1948,
#  'still': 1703,
#  'robert': 1530,
#  'lee': 995,
#  'great': 756,
#  'tear': 1765,
#  'speak': 1668,
#  'bad': 166,
#  'sad': 1545,
#  'difficult': 499,
#  'condemn': 361,
#  'violent': 1901,
#  'civil': 312,
#  'war': 1917,
#  'general': 731,
#  'whose': 1954,
#  'protest': 1385,
#  'violence': 1900,
#  'virginia': 1902,
#  'weekend': 1935,
#  'plan': 1298,
#  'supremacist': 1740,
#  'city': 311,
#  'remove': 1470,
#  'after': 47,
#  'council': 405,
#  'vote': 1907,
#  'harm': 779,
#  'well': 1938,
#  'place': 1297,
#  'refer': 1444,
#  'protester': 1386,
#  'march': 1054,
#  'charlottesville': 291,
#  'friday': 711,
#  'hate': 783,
#  'mention': 1082,
#  'name': 1135,
#  'young': 1996,
#  'job': 928,
#  'denounce': 477,
#  'nazi': 1143,
#  'don': 527,
#  'quick': 1406,
#  'defend': 465,
#  'sort': 1663,
#  'behavior': 187,
#  'union': 1866,
#  'together': 1814,
#  'country': 409,
#  'hide': 800,
#  'behind': 188,
#  'life': 1010,
#  'act': 18,
#  'occur': 1192,
#  'saturday': 1555,
#  'remain': 1466,
#  'yes': 1991,
#  'absolutely': 7,
#  'option': 1223,
#  'move': 1122,
#  'look': 1032,
#  'extremely': 631,
#  'understand': 1864,
#  'period': 1284,
#  'sense': 1592,
#  'word': 1974,
#  'american': 85,
#  'history': 809,
#  'right': 1524,
#  'original': 1228,
#  'military': 1092,
#  'leader': 988,
#  'write': 1984,
#  'propose': 1381,
#  'open': 1214,
#  'example': 613,
#  'commit': 343,
#  'chip': 299,
#  'somodevilla': 1659,
#  'anti': 105,
#  'activist': 20,
#  'bill': 201,
#  'september': 1597,
#  'reuters': 1509,
#  'discussion': 512,
#  'overhaul': 1239,
#  'code': 329,
#  'advocate': 40,
#  'wednesday': 1933,
#  'produce': 1365,
#  'corporate': 398,
#  'cut': 434,
#  'head': 788,
#  'americans': 86,
#  'reform': 1447,
#  'lobbyist': 1027,
#  'big': 199,
#  'six': 1641,
#  'group': 759,
#  'decision': 458,
#  'target': 1760,
#  'end': 576,
#  'introduce': 896,
#  'senate': 1588,
#  'meet': 1077,
#  'couple': 411,
#  'package': 1245,
#  'small': 1646,
#  'evening': 603,
#  'minute': 1100,
#  'later': 979,
#  'principle': 1353,
#  'offer': 1198,
#  'comment': 340,
#  'agree': 55,
#  'page': 1247,
#  'economic': 552,
#  'adviser': 38,
#  'gary': 727,
#  'cohn': 330,
#  'representative': 1482,
#  'way': 1926,
#  'mean': 1069,
#  'chairman': 282,
#  'kevin': 952,
#  'brady': 224,
#  'also': 77,
#  'reporter': 1480,
#  'expect': 621,
#  'day': 446,
#  'central': 276,
#  'percent': 1278,
#  'income': 860,
#  'rate': 1421,
#  'permanent': 1285,
#  'slash': 1644,
#  'seven': 1607,
#  'settle': 1606,
#  'deficit': 467,
#  'treasury': 1834,
#  'steven': 1701,
#  'mnuchin': 1107,
#  'really': 1433,
#  'corporation': 399,
#  'majority': 1044,
#  'mitch': 1106,
#  'mcconnell': 1067,
#  'speaker': 1669,
#  'paul': 1267,
#  'ryan': 1544,
#  'finance': 671,
#  'hatch': 782,
#  'play': 1302,
#  'key': 953,
#  'role': 1531,
#  'negotiation': 1151,
#  'insist': 876,
#  'lower': 1038,
#  'pass': 1262,
#  'top': 1818,
#  'individual': 866,
#  'achieve': 15,
#  'basis': 177,
#  'federal': 656,
#  'administration': 30,
#  'revenue': 1511,
#  'loss': 1034,
#  'trillion': 1838,
#  'decade': 455,
#  'independent': 864,
#  'analyst': 92,
#  'temporary': 1770,
#  'conflict': 368,
#  'ensure': 584,
#  'presidency': 1339,
#  'morning': 1116,
#  'debt': 453,
#  'responsible': 1501,
#  'impact': 847,
#  'economy': 553,
#  'cost': 402,
#  'under': 1862,
#  'current': 431,
#  'company': 349,
#  'schedule': 1561,
#  'long': 1031,
#  'wear': 1931,
#  'lose': 1033,
#  'value': 1883,
#  'expense': 622,
#  'policy': 1308,
#  'entire': 586,
#  'price': 1349,
#  'purchase': 1398,
#  'barack': 174,
#  'help': 795,
#  'reverse': 1512,
#  'office': 1199,
#  'consider': 375,
#  'three': 1803,
#  'tillerson': 1809,
#  'pressure': 1343,
#  'north': 1174,
#  'korea': 964,
#  'rex': 1515,
#  'sunday': 1735,
#  'firing': 676,
#  'missile': 1103,
#  'week': 1934,
#  'resolution': 1494,
#  'view': 1897,
#  'ally': 72,
#  'fox': 703,
#  'describe': 483,
#  'china': 297,
#  'pyongyang': 1404,
#  'negotiate': 1150,
#  'table': 1751,
#  'arrive': 134,
#  'ahead': 57,
#  'summit': 1734,
#  'thursday': 1807,
#  'stance': 1685,
#  'trade': 1828,
#  'climate': 320,
#  'change': 286,
#  'meeting': 1078,
#  'town': 1826,
#  'last': 977,
#  'nine': 1163,
#  'middle': 1088,
#  'east': 550,
#  'europe': 600,
#  'foreign': 696,
#  'trip': 1839,
#  'january': 921,
#  'visit': 1904,
#  'saudi': 1556,
#  'arabia': 123,
#  'israel': 910,
#  'hold': 811,
#  'european': 601,
#  'nato': 1141,
#  'alliance': 70,
#  'plane': 1299,
#  'land': 972,
#  'due': 541,
#  'fly': 687,
#  'tweet': 1853,
#  'inc': 857,
#  'send': 1590,
#  'message': 1083,
#  'especially': 595,
#  'large': 974,
#  'investment': 900,
#  'bank': 171,
#  'ban': 170,
#  'its': 914,
#  'kind': 958,
#  'struggle': 1718,
#  'memo': 1081,
#  'employee': 572,
#  'effective': 557,
#  'across': 17,
#  'firm': 677,
#  'activity': 21,
#  'us': 1879,
#  'below': 191,
#  'prohibit': 1372,
#  'engage': 581,
#  'run': 1540,
#  'local': 1028,
#  'sit': 1638,
#  'prevent': 1346,
#  'violate': 1898,
#  'pay': 1268,
#  'rule': 1538,
#  'particularly': 1258,
#  'provision': 1390,
#  'transition': 1832,
#  'into': 895,
#  'cover': 414,
#  'fail': 636,
#  'comply': 355,
#  'fine': 674,
#  'client': 319,
#  'particular': 1257,
#  'potential': 1327,
#  'cause': 271,
#  'false': 641,
#  'give': 741,
#  'failure': 637,
#  'pre': 1334,
#  'seriously': 1600,
#  'violation': 1899,
#  'result': 1504,
#  'damn': 439,
#  'specifically': 1672,
#  'type': 1856,
#  'donation': 529,
#  'governor': 751,
#  'vice': 1892,
#  'pence': 1272,
#  'mayor': 1065,
#  'here': 797,
#  'position': 1321,
#  'yet': 1993,
#  'only': 1213,
#  'pick': 1292,
#  'mike': 1090,
#  'senator': 1589,
#  'although': 80,
#  'democratic': 474,
#  'ceo': 277,
#  'hasn': 781,
#  'knowledge': 963,
#  'fan': 644,
#  'read': 1427,
#  'full': 717,
#  'obtain': 1189,
#  'popular': 1318,
#  'increasingly': 862,
#  'sure': 1742,
#  'process': 1364,
#  'count': 407,
#  'texas': 1780,
#  'voting': 1909,
#  'california': 249,
#  'politic': 1309,
#  'national': 1138,
#  'possible': 1324,
#  'support': 1737,
#  'ballot': 169,
#  'cast': 268,
#  'couldn': 404,
#  'afford': 43,
#  'too': 1816,
#  'sign': 1629,
#  'worth': 1980,
#  'determine': 490,
#  'live': 1023,
#  'jersey': 925,
#  'illinois': 840,
#  'island': 908,
#  'hawaii': 786,
#  'your': 1997,
#  'district': 517,
#  'board': 213,
#  'mostly': 1119,
#  'blue': 212,
#  'legislative': 999,
#  'branch': 226,
#  'join': 932,
#  'progress': 1371,
#  'movement': 1123,
#  'alex': 65,
#  'wong': 1973,
#  'flight': 684,
#  'demand': 471,
#  'trumpcare': 1845,
#  'tough': 1822,
#  'citizen': 310,
#  'answer': 103,
#  'disgusting': 513,
#  'repeal': 1472,
#  'replacement': 1476,
#  'resident': 1491,
#  'brown': 236,
#  'same': 1549,
#  'sen': 1587,
#  'james': 919,
#  'listen': 1020,
#  'voice': 1906,
#  'anyone': 108,
#  'health': 789,
#  'care': 263,
#  'previously': 1348,
#  'letter': 1003,
#  'far': 645,
#  'unable': 1860,
#  'response': 1499,
#  'opportunity': 1220,
#  'facebook': 634,
#  'soon': 1661,
#  'ask': 139,
#  'attention': 153,
#  'twitter': 1854,
#  'replace': 1475,
#  'obamacare': 1187,
#  'user': 1881,
#  'begin': 185,
#  'suggest': 1731,
#  'approach': 118,
#  'note': 1176,
#  'must': 1132,
#  'actually': 23,
#  'my': 1133,
#  'story': 1708,
#  'hear': 791,
#  'important': 852,
#  'conversation': 390,
#  'agreement': 56,
#  'future': 724,
#  'forward': 700,
#  'might': 1089,
#  'phone': 1290,
#  'address': 29,
#  'concern': 357,
#  'early': 546,
#  'hall': 770,
#  'isn': 909,
#  'everyone': 609,
#  'social': 1650,
#  'media': 1073,
#  'account': 12,
#  'comey': 339,
#  'confirm': 366,
#  'flynn': 688,
#  'cnn': 325,
#  'director': 505,
#  'michael': 1086,
#  'testimony': 1779,
#  'cite': 309,
#  'source': 1665,
#  'fire': 675,
#  'testify': 1778,
#  'before': 184,
#  'panel': 1249,
#  'publicly': 1393,
#  'monday': 1111,
#  'probe': 1361,
#  'february': 654,
#  'oval': 1236,
#  'contact': 382,
#  'ambassador': 82,
#  'times': 1811,
#  'base': 175,
#  'raise': 1415,
#  'special': 1670,
#  'counsel': 406,
#  'colleague': 332,
#  'bureau': 241,
#  'welcome': 1937,
#  'announcement': 99,
#  'spokeswoman': 1679,
#  'richard': 1518,
#  'immigration': 846,
#  'enforcement': 580,
#  'tuesday': 1849,
#  'police': 1307,
#  'deportation': 481,
#  'turn': 1851,
#  'legal': 997,
#  'authority': 158,
#  'request': 1486,
#  'hour': 822,
#  'system': 1750,
#  'cooperate': 394,
#  'dangerous': 441,
#  'murder': 1130,
#  'rape': 1420,
#  'safe': 1546,
#  'honor': 815,
#  'specific': 1671,
#  'proposal': 1380,
#  'limit': 1015,
#  'where': 1945,
#  'suspect': 1746,
#  'terrorism': 1775,
#  'street': 1713,
#  'human': 827,
#  'directly': 504,
#  'relate': 1458,
#  'status': 1694,
#  'apply': 115,
#  'immigrant': 845,
#  'illegally': 839,
#  'arrest': 133,
#  'otherwise': 1230,
#  'enter': 585,
#  'require': 1487,
#  'judge': 939,
#  'approval': 120,
#  'resolve': 1495,
#  'illegal': 838,
#  'priority': 1355,
#  'criticize': 425,
#  'legislation': 998,
#  'executive': 617,
#  'rise': 1526,
#  'control': 387,
#  'legislature': 1000,
#  'immediately': 844,
#  'respond': 1498,
#  'ross': 1534,
#  'moscow': 1117,
#  'commerce': 341,
#  'sanction': 1551,
#  'impose': 853,
#  'ukraine': 1857,
#  'crisis': 421,
#  'supply': 1736,
#  'service': 1602,
#  'associate': 146,
#  'subject': 1723,
#  'half': 769,
#  'spend': 1675,
#  'million': 1094,
#  'overall': 1238,
#  'never': 1155,
#  'ship': 1616,
#  'product': 1366,
#  'management': 1049,
#  'gas': 728,
#  'connection': 372,
#  'counter': 408,
#  'conduct': 363,
#  'necessary': 1147,
#  'restriction': 1503,
#  'surprise': 1743,
#  'medium': 1076,
#  'reflect': 1446,
#  'publish': 1394,
#  'another': 102,
#  'reply': 1477,
#  'reuter': 1508,
#  'spokesman': 1678,
#  'vehicle': 1886,
#  'decline': 460,
#  'sean': 1571,
#  'spicer': 1677,
#  'brand': 227,
#  'video': 1895,
#  'oh': 1203,
#  'mr': 1124,
#  'favorite': 649,
#  'press': 1342,
#  'around': 132,
#  'own': 1243,
#  'stuff': 1721,
#  'relationship': 1460,
#  'today': 1813,
#  'between': 195,
#  'away': 163,
#  'leave': 994,
#  'corp': 397,
#  'among': 88,
#  'few': 662,
#  'apparently': 111,
#  'feed': 658,
#  'steve': 1700,
#  'bob': 214,
#  'die': 496,
#  'thousand': 1800,
#  'death': 451,
#  'wish': 1964,
#  'free': 709,
#  'rep': 1471,
#  'huge': 826,
#  'grab': 752,
#  'field': 663,
#  'girl': 739,
#  'kid': 955,
#  'development': 492,
#  'mother': 1120,
#  'jones': 935,
#  'market': 1056,
#  'watch': 1924,
#  'toward': 1823,
#  'conclude': 359,
#  'perhaps': 1283,
#  'alternative': 79,
#  'present': 1338,
#  'budget': 237,
#  'payment': 1269,
#  'rank': 1418,
#  'border': 220,
#  'shutdown': 1626,
#  'supporter': 1738,
#  'unfortunately': 1865,
#  ...}

# %%
# First sample of training text
X_train.iloc[0]
# Out:
# 'fact check intelligence prove trump a liar he know about russian attack donald trump seem to be willfully ignorant when it come to a russian cyber security threat he display this once again during the second presidential state that he didn t know whether there be russian involvement in regard to hack and the election but that s an outright lie intelligence have be brief he on this very to nbc news a senior intelligence official assure nbc news that cybersecurity and the russian government s attempt to interfere in the election have be brief to and discuss extensively with both party candidate surrogate and leadership since mid august to profess not to know at this point be willful misrepresentation say the official the intelligence community have walk a very thin line in not take side but both candidate have all the information they need to be crystal clear thus prove without a doubt that trump either have amnesia or willingly lie during the debate regard cyber security and the debate trump profess I notice anytime anything wrong happen they like to say the russians be hillary clinton doesn t know if it s the russians do the hacking maybe there be no hacking but they always blame russia and the reason they blame russia because they think they re try to tarnish I with russia I know nothing about russia trump literally bring it back to himself that hillary talk about russia s hacking be all about he he need to realize that hillary bring it up to express the very critical point of increase cyber security you know like an actual fact go beyond the intelligence briefing that he be undoubtedly privy to the intelligence community make this statement public for all of we to know the intelligence community usic be confident that the russian government direct the recent compromise of e mail from person and institution include from political organization so this beg the question why be trump either ignore this issue or try to protect bring up the fact that trump may have russian business tie but we wouldn t know because he win t release his taxis trump have already boast how much he love russian president vladimir putin and this blatant lie during the debate definitely seem fact accord to the washington post there be strong evidence that trump s business have receive significant funding from russian investor most notably trump s son donald trump jr make that very claim at a real estate conference in new york in say russian make up a pretty disproportionate cross section of a lot of our asset donald trump jr add we see a lot of money pour in from russia which lead many to believe that trump s business tie may be the reason for his willful ignorance when it come to cyber security and would definitely know more if the republican candidate release his taxis however know they ll likely be damage he ll probably keep those pretty close to his orange this report via nbc news regard the hack feature photo by win mcnamee getty image'

# %%
# First sample of vectorized training text
print(X_train_vect[0])
# Out:
#   (0, 635)	0.10897484299872526
#   (0, 292)	0.04466108081061239
#   (0, 885)	0.2376286430090696
#   (0, 1387)	0.07421007749313771
#   (0, 1844)	0.15989926920727565
#   (0, 1006)	0.05224058778800144
#   (0, 787)	0.12815259568389134
#   (0, 962)	0.21121546315290027
#   (0, 5)	0.06330092808473571
#   (0, 1542)	0.2773721091147251
#   (0, 150)	0.029375278996492168
#   (0, 528)	0.041053240575949064
#   (0, 1583)	0.06230621566430067
#   (0, 1812)	0.22443838502276442
#   (0, 179)	0.16242126278479108
#   (0, 1944)	0.037470843568818184
#   (0, 913)	0.06233617920567271
#   (0, 338)	0.04333706573675609
#   (0, 435)	0.21597121917856105
#   (0, 1580)	0.11456870020661825
#   (0, 1801)	0.03728177782649713
#   (0, 515)	0.053160189338006925
#   (0, 1796)	0.1145151615267912
#   (0, 1209)	0.034263639382361245
#   (0, 48)	0.03042061325307966
#   :	:
#   (0, 1112)	0.034236883037227064
#   (0, 1947)	0.018072418380519657
#   (0, 987)	0.02909231916372689
#   (0, 1052)	0.025126633321196384
#   (0, 190)	0.029207916026727457
#   (0, 1981)	0.016167723758764765
#   (0, 1115)	0.018342148710343155
#   (0, 1484)	0.020488093546784016
#   (0, 825)	0.03224558907564137
#   (0, 1024)	0.07646441727925665
#   (0, 1014)	0.03236802989481184
#   (0, 438)	0.04370273855491875
#   (0, 1360)	0.03722844507740981
#   (0, 947)	0.028626447741188023
#   (0, 1797)	0.025343260390491253
#   (0, 322)	0.032778961813483797
#   (0, 1225)	0.05276725372209488
#   (0, 1478)	0.026021129113015042
#   (0, 1891)	0.01925662222258109
#   (0, 653)	0.035408469994581526
#   (0, 1291)	0.042556539489494956
#   (0, 247)	0.013476248769928907
#   (0, 1068)	0.049882239227597304
#   (0, 738)	0.022657145989801356
#   (0, 841)	0.017960121648599264

# %%
# Training and testing the model
model = RandomForestClassifier()

model.fit(X_train_vect, y_train)

y_pred = model.predict(X_test_vect)

print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1267
#            1       1.00      1.00      1.00      1208
#
#     accuracy                           1.00      2475
#    macro avg       1.00      1.00      1.00      2475
# weighted avg       1.00      1.00      1.00      2475

# %% [markdown]
# ## Pros of TF-IDF:
#
# * Simplicity: TF-IDF is straightforward to calculate and understand, making it a good starting point for text analysis tasks.
#
# * Identifies important words: By considering both how often a word appears in a document (term frequency) and how rare it is across the corpus (inverse document frequency), TF-IDF effectively highlights key terms within a document.
#
# * Scalability: It can be applied to large datasets with a large number of documents efficiently.
#
# * Language-agnostic: TF-IDF works well across different languages without requiring language-specific adjustments.
#
# ## Cons of TF-IDF:
#
# * No semantic understanding: TF-IDF only considers word frequency, not their contextual meaning, so it can't differentiate between words with similar spellings but different meanings.
#
# * Ignores word order: As a bag-of-words model, TF-IDF doesn't take into account the sequence of words in a sentence, potentially missing important nuances.
#
# * Sensitivity to stop words: Common words like "the" or "and" can have high TF-IDF scores if not properly handled with stop word removal.
# Potential for misinterpretation: In certain cases, rare words appearing only in a few documents might have high TF-IDF scores even if they are not semantically important.
#
# * Curse of dimensionality: When dealing with a large vocabulary, TF-IDF vectors can become very high-dimensional, potentially causing computational issues.
